# %% [markdown]
# # Getting started
# ColorQuantization.jl can be applied to any iterable collection of Colorants `img`,
# e.g. an image or any `AbstractArray`.
# We demonstrate ColorQuantization.jl on the peppers test image:

# %%
using ColorQuantization
using ColorTypes
using TestImages

img = testimage("peppers")
# Out:
#  Downloading artifact: images
# 512×512 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.396,0.0,0.0)  …  RGB{N0f8}(0.471,0.0,0.71)
#  RGB{N0f8}(0.482,0.0,0.0)     RGB{N0f8}(0.451,0.753,0.333)
#  RGB{N0f8}(0.494,0.0,0.0)     RGB{N0f8}(0.443,0.765,0.341)
#  RGB{N0f8}(0.482,0.0,0.0)     RGB{N0f8}(0.463,0.769,0.349)
#  RGB{N0f8}(0.498,0.0,0.0)     RGB{N0f8}(0.463,0.784,0.329)
#  RGB{N0f8}(0.486,0.0,0.0)  …  RGB{N0f8}(0.463,0.773,0.329)
#  RGB{N0f8}(0.467,0.0,0.0)     RGB{N0f8}(0.459,0.773,0.325)
#  RGB{N0f8}(0.471,0.0,0.0)     RGB{N0f8}(0.451,0.78,0.322)
#  RGB{N0f8}(0.455,0.0,0.0)     RGB{N0f8}(0.451,0.78,0.349)
#  RGB{N0f8}(0.424,0.0,0.0)     RGB{N0f8}(0.439,0.769,0.333)
#  ⋮                         ⋱
#  RGB{N0f8}(0.478,0.0,0.0)     RGB{N0f8}(0.722,0.816,0.655)
#  RGB{N0f8}(0.471,0.0,0.0)     RGB{N0f8}(0.749,0.804,0.659)
#  RGB{N0f8}(0.463,0.0,0.0)  …  RGB{N0f8}(0.741,0.835,0.682)
#  RGB{N0f8}(0.4,0.0,0.0)       RGB{N0f8}(0.714,0.835,0.604)
#  RGB{N0f8}(0.396,0.0,0.0)     RGB{N0f8}(0.718,0.812,0.643)
#  RGB{N0f8}(0.361,0.0,0.0)     RGB{N0f8}(0.749,0.835,0.706)
#  RGB{N0f8}(0.361,0.0,0.0)     RGB{N0f8}(0.741,0.773,0.506)
#  RGB{N0f8}(0.361,0.0,0.0)  …  RGB{N0f8}(0.769,0.647,0.459)
#  RGB{N0f8}(0.365,0.0,0.0)     RGB{N0f8}(0.776,0.784,0.671)

# %% [markdown]
# To extract a color palette from an image, call `quantize`
# with a quantization method of your choice.

# %% [markdown]
# ## Clustering
# Clustering methods such as `KMeansQuantization` are convenient since they allow us
# to specify the exact number of output colors:

# %%
quantize(img, KMeansQuantization(16))
# Out:
# 16-element Array{RGB{N0f8},1} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.596,0.11,0.11)
#  RGB{N0f8}(0.565,0.733,0.455)
#  RGB{N0f8}(0.302,0.302,0.157)
#  RGB{N0f8}(0.773,0.204,0.169)
#  RGB{N0f8}(0.38,0.145,0.098)
#  RGB{N0f8}(0.494,0.345,0.184)
#  RGB{N0f8}(0.392,0.396,0.243)
#  RGB{N0f8}(0.733,0.345,0.231)
#  RGB{N0f8}(0.49,0.667,0.337)
#  RGB{N0f8}(0.694,0.804,0.612)
#  RGB{N0f8}(0.616,0.549,0.278)
#  RGB{N0f8}(0.725,0.796,0.369)
#  RGB{N0f8}(0.275,0.059,0.043)
#  RGB{N0f8}(0.812,0.498,0.412)
#  RGB{N0f8}(0.455,0.533,0.259)
#  RGB{N0f8}(0.647,0.718,0.318)

# %%
quantize(img, KMeansQuantization(64))
# Out:
# 64-element Array{RGB{N0f8},1} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.494,0.518,0.263)
#  RGB{N0f8}(0.831,0.302,0.231)
#  RGB{N0f8}(0.341,0.098,0.078)
#  RGB{N0f8}(0.765,0.827,0.678)
#  RGB{N0f8}(0.463,0.651,0.29)
#  RGB{N0f8}(0.29,0.243,0.118)
#  RGB{N0f8}(0.553,0.055,0.071)
#  RGB{N0f8}(0.686,0.796,0.51)
#  RGB{N0f8}(0.659,0.596,0.361)
#  RGB{N0f8}(0.62,0.702,0.31)
#  ⋮
#  RGB{N0f8}(0.459,0.357,0.188)
#  RGB{N0f8}(0.82,0.224,0.165)
#  RGB{N0f8}(0.471,0.443,0.224)
#  RGB{N0f8}(0.431,0.588,0.263)
#  RGB{N0f8}(0.788,0.212,0.169)
#  RGB{N0f8}(0.561,0.753,0.467)
#  RGB{N0f8}(0.624,0.078,0.082)
#  RGB{N0f8}(0.757,0.859,0.776)
#  RGB{N0f8}(0.753,0.812,0.576)

# %%
quantize(img, KMeansQuantization(256))
# Out:
# ┌ Warning: The clustering cost increased at iteration #44
# └ @ Clustering ~/.julia/packages/Clustering/yuxBr/src/kmeans.jl:191
# 256-element Array{RGB{N0f8},1} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.776,0.176,0.161)
#  RGB{N0f8}(0.506,0.71,0.271)
#  RGB{N0f8}(0.333,0.047,0.047)
#  RGB{N0f8}(0.824,0.525,0.435)
#  RGB{N0f8}(0.682,0.831,0.412)
#  RGB{N0f8}(0.427,0.463,0.2)
#  RGB{N0f8}(0.78,0.722,0.384)
#  RGB{N0f8}(0.357,0.106,0.082)
#  RGB{N0f8}(0.757,0.816,0.58)
#  RGB{N0f8}(0.678,0.145,0.149)
#  ⋮
#  RGB{N0f8}(0.49,0.69,0.318)
#  RGB{N0f8}(0.51,0.216,0.118)
#  RGB{N0f8}(0.451,0.69,0.322)
#  RGB{N0f8}(0.659,0.541,0.192)
#  RGB{N0f8}(0.702,0.78,0.431)
#  RGB{N0f8}(0.412,0.051,0.059)
#  RGB{N0f8}(0.58,0.059,0.075)
#  RGB{N0f8}(0.286,0.055,0.063)
#  RGB{N0f8}(0.541,0.122,0.086)

# %% [markdown]
# ## Uniform quantization
# If perfomance is crucial, `UniformQuantization` can be used to quantize colors
# to the closest points on a equidistant 3D grid.

# %%
quantize(img, UniformQuantization(4))
# Out:
# 52-element Array{RGB{N0f8},1} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.376,0.125,0.125)
#  RGB{N0f8}(0.125,0.125,0.125)
#  RGB{N0f8}(0.627,0.125,0.125)
#  RGB{N0f8}(0.875,0.125,0.125)
#  RGB{N0f8}(0.627,0.125,0.627)
#  RGB{N0f8}(0.875,0.376,0.125)
#  RGB{N0f8}(0.627,0.376,0.125)
#  RGB{N0f8}(0.627,0.627,0.376)
#  RGB{N0f8}(0.875,0.627,0.376)
#  RGB{N0f8}(0.875,0.627,0.125)
#  ⋮
#  RGB{N0f8}(0.875,0.627,0.875)
#  RGB{N0f8}(0.125,0.125,0.376)
#  RGB{N0f8}(0.125,0.125,0.875)
#  RGB{N0f8}(0.627,0.627,0.875)
#  RGB{N0f8}(0.376,0.627,0.875)
#  RGB{N0f8}(0.125,0.376,0.376)
#  RGB{N0f8}(0.125,0.875,0.627)
#  RGB{N0f8}(0.125,0.875,0.376)
#  RGB{N0f8}(0.125,0.627,0.376)

# %%
quantize(img, UniformQuantization(6))
# Out:
# 116-element Array{RGB{N0f8},1} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.416,0.082,0.082)
#  RGB{N0f8}(0.251,0.082,0.082)
#  RGB{N0f8}(0.082,0.082,0.082)
#  RGB{N0f8}(0.584,0.082,0.082)
#  RGB{N0f8}(0.749,0.082,0.082)
#  RGB{N0f8}(0.918,0.082,0.082)
#  RGB{N0f8}(0.584,0.082,0.584)
#  RGB{N0f8}(0.749,0.416,0.251)
#  RGB{N0f8}(0.749,0.251,0.251)
#  RGB{N0f8}(0.749,0.584,0.251)
#  ⋮
#  RGB{N0f8}(0.251,0.416,0.416)
#  RGB{N0f8}(0.251,0.749,0.251)
#  RGB{N0f8}(0.416,0.918,0.416)
#  RGB{N0f8}(0.416,0.918,0.251)
#  RGB{N0f8}(0.251,0.749,0.584)
#  RGB{N0f8}(0.082,0.749,0.416)
#  RGB{N0f8}(0.082,0.251,0.082)
#  RGB{N0f8}(0.082,0.251,0.251)
#  RGB{N0f8}(0.584,0.918,0.918)

# %%
quantize(img, UniformQuantization(8))
# Out:
# 203-element Array{RGB{N0f8},1} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.439,0.063,0.063)
#  RGB{N0f8}(0.314,0.063,0.063)
#  RGB{N0f8}(0.188,0.063,0.063)
#  RGB{N0f8}(0.063,0.063,0.063)
#  RGB{N0f8}(0.565,0.063,0.063)
#  RGB{N0f8}(0.686,0.063,0.063)
#  RGB{N0f8}(0.812,0.063,0.063)
#  RGB{N0f8}(0.565,0.063,0.565)
#  RGB{N0f8}(0.686,0.439,0.188)
#  RGB{N0f8}(0.686,0.314,0.188)
#  ⋮
#  RGB{N0f8}(0.314,0.812,0.565)
#  RGB{N0f8}(0.188,0.812,0.565)
#  RGB{N0f8}(0.314,0.812,0.439)
#  RGB{N0f8}(0.188,0.686,0.439)
#  RGB{N0f8}(0.188,0.812,0.439)
#  RGB{N0f8}(0.188,0.686,0.314)
#  RGB{N0f8}(0.188,0.565,0.314)
#  RGB{N0f8}(0.063,0.188,0.188)
#  RGB{N0f8}(0.565,0.937,0.812)

# %% [markdown]
# Using `UniformQuantization`, every single pixel in the input image is rounded
# and appears in the generated color palette, which explains the blues and purples
# from the shadows of the peppers.

# %% [markdown]
# # Output color type
# It is also possible to specify the output color type:

# %%
colors = quantize(HSV, img, UniformQuantization(4))
# Out:
# 52-element Array{HSV{Float32},1} with eltype ColorTypes.HSV{Float32}:
#  HSV{Float32}(0.0f0,0.66666657f0,0.3764706f0)
#  HSV{Float32}(0.0f0,0.0f0,0.1254902f0)
#  HSV{Float32}(0.0f0,0.8f0,0.627451f0)
#  HSV{Float32}(0.0f0,0.85650223f0,0.8745098f0)
#  HSV{Float32}(300.0f0,0.8f0,0.627451f0)
#  HSV{Float32}(20.10471f0,0.85650223f0,0.8745098f0)
#  HSV{Float32}(29.999994f0,0.8f0,0.627451f0)
#  HSV{Float32}(59.999996f0,0.4f0,0.627451f0)
#  HSV{Float32}(30.236221f0,0.5695067f0,0.8745098f0)
#  HSV{Float32}(40.209427f0,0.85650223f0,0.8745098f0)
#  ⋮
#  HSV{Float32}(300.0f0,0.2825112f0,0.8745098f0)
#  HSV{Float32}(240.0f0,0.66666657f0,0.3764706f0)
#  HSV{Float32}(240.0f0,0.85650223f0,0.8745098f0)
#  HSV{Float32}(240.0f0,0.2825112f0,0.8745098f0)
#  HSV{Float32}(209.76378f0,0.5695067f0,0.8745098f0)
#  HSV{Float32}(180.0f0,0.6666666f0,0.3764706f0)
#  HSV{Float32}(160.20943f0,0.85650223f0,0.8745098f0)
#  HSV{Float32}(140.1047f0,0.85650223f0,0.8745098f0)
#  HSV{Float32}(150.0f0,0.8f0,0.627451f0)

# %%
typeof(colors)
# Out:
# Vector{HSV{Float32}} (alias for Array{ColorTypes.HSV{Float32}, 1})

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
